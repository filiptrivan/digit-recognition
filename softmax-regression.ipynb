# %%
import utils
import numpy as np

# %%
training_data = utils.get_train_data()
test_data = utils.get_test_data()

# %%
X = np.array(training_data.drop(columns=['label']))
y = np.array(training_data['label'])
W, B, cost_history = utils.train_softmax_regression(X, y, alpha=0.00001, lambd=0.5, epochs=50, num_classes=10)

utils.plot_cost(cost_history)

# %%
res = utils.predict(np.array([test_data.iloc[4]]), W, B)
print(res[0])
# Out:
# 3
